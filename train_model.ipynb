# %%
# !pip install tensorflow opencv-python mediapipe scikit-learn
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Collecting mediapipe
#   Downloading mediapipe-0.10.21-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.75.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.12/dist-packages (from mediapipe) (25.3.0)
# Requirement already satisfied: jax in /usr/local/lib/python3.12/dist-packages (from mediapipe) (0.5.3)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.12/dist-packages (from mediapipe) (0.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mediapipe) (3.10.0)
# INFO: pip is looking at multiple versions of mediapipe to determine which version is compatible with other requirements. This could take a while.
#   Downloading mediapipe-0.10.20-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
#   Downloading mediapipe-0.10.18-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
#   Downloading mediapipe-0.10.15-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
#   Downloading mediapipe-0.10.14-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.12/dist-packages (from mediapipe) (4.12.0.88)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 (from tensorflow)
#   Downloading protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.5.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.12/dist-packages (from sounddevice>=0.4.4->mediapipe) (2.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mediapipe) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mediapipe) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mediapipe) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mediapipe) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mediapipe) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.23)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading mediapipe-0.10.14-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 26.4 MB/s eta 0:00:00
# Downloading protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 21.1 MB/s eta 0:00:00
# Downloading sounddevice-0.5.2-py3-none-any.whl (32 kB)
# Installing collected packages: protobuf, sounddevice, mediapipe
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.8 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.8 which is incompatible.
# Successfully installed mediapipe-0.10.14 protobuf-4.25.8 sounddevice-0.5.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
import os
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense
from tensorflow.keras.callbacks import TensorBoard
import tensorflow as tf
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision
from mediapipe import solutions
from mediapipe.framework.formats import landmark_pb2
import warnings

# Suppress Protobuf deprecation warning from MediaPipe
warnings.filterwarnings("ignore", category=UserWarning, module='google.protobuf.symbol_database')

# --- Part 1: Configuration & Setup ---

DATA_PATH = "/content/drive/MyDrive/samples"
actions = np.array(['obrigado', 'null'])
sequence_length = 100

pose_model_path = 'pose_landmarker_lite.task'
hand_model_path = 'hand_landmarker.task'
if not os.path.exists(pose_model_path) or not os.path.exists(hand_model_path):
    print("="*80)
    print("ERROR: Please download the required MediaPipe models and place them in this directory.")
    exit()

# **FIX: Switched to the more stable IMAGE mode for processing**
base_options = python.BaseOptions
PoseLandmarker = vision.PoseLandmarker
PoseLandmarkerOptions = vision.PoseLandmarkerOptions
HandLandmarker = vision.HandLandmarker
HandLandmarkerOptions = vision.HandLandmarkerOptions
VisionRunningMode = vision.RunningMode

pose_options = PoseLandmarkerOptions(
    base_options=base_options(model_asset_path=pose_model_path), running_mode=VisionRunningMode.IMAGE)
hand_options = HandLandmarkerOptions(
    base_options=base_options(model_asset_path=hand_model_path), running_mode=VisionRunningMode.IMAGE, num_hands=2)


# --- Part 2: Keypoint Extraction Function ---
def extract_keypoints(pose_result, hand_result):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in pose_result.pose_landmarks[0]]).flatten() if pose_result.pose_landmarks else np.zeros(33 * 4)
    lh, rh = np.zeros(21 * 3), np.zeros(21 * 3)
    if hand_result.hand_landmarks:
        for i, hand_landmarks in enumerate(hand_result.hand_landmarks):
            handedness = hand_result.handedness[i][0].category_name
            if handedness == "Left": lh = np.array([[res.x, res.y, res.z] for res in hand_landmarks]).flatten()
            elif handedness == "Right": rh = np.array([[res.x, res.y, res.z] for res in hand_landmarks]).flatten()
    return np.concatenate([pose, lh, rh])

# --- Part 3: Video Processing and Data Loading ---
def process_videos_and_load_data():
    print("Starting video processing and data loading...")
    label_map = {label: num for num, label in enumerate(actions)}
    sequences, labels = [], []

    with PoseLandmarker.create_from_options(pose_options) as pose_landmarker, \
         HandLandmarker.create_from_options(hand_options) as hand_landmarker:

        for action in actions:
            action_path = os.path.join(DATA_PATH, action)
            if not os.path.isdir(action_path):
                print(f"Warning: Directory not found for action '{action}': {action_path}")
                continue

            print(f"Processing videos for action: '{action}'")
            for video_file in os.listdir(action_path):
                if not video_file.lower().endswith('.mp4'):
                    continue

                video_path = os.path.join(action_path, video_file)
                cap = cv2.VideoCapture(video_path)

                frame_landmarks = []
                while True:
                    ret, frame = cap.read()
                    if not ret:
                        break

                    mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

                    # **FIX: Using simple 'detect' since we are in IMAGE mode**
                    pose_result = pose_landmarker.detect(mp_image)
                    hand_result = hand_landmarker.detect(mp_image)

                    keypoints = extract_keypoints(pose_result, hand_result)
                    frame_landmarks.append(keypoints)

                cap.release()

                if len(frame_landmarks) > 0:
                    if len(frame_landmarks) >= sequence_length:
                        indices = np.linspace(0, len(frame_landmarks) - 1, sequence_length, dtype=int)
                        sampled_landmarks = [frame_landmarks[i] for i in indices]
                    else:
                        sampled_landmarks = frame_landmarks
                        padding = [frame_landmarks[-1]] * (sequence_length - len(frame_landmarks))
                        sampled_landmarks.extend(padding)

                    sequences.append(sampled_landmarks)
                    labels.append(label_map[action])

    return np.array(sequences), to_categorical(labels).astype(int)

# --- Part 4: Training the Model ---
def train_model():
    X, y = process_videos_and_load_data()

    if X.shape[0] == 0:
        print("Error: No data was loaded. Please check your DATA_PATH and video files.")
        return

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15)

    print(f"\nData successfully loaded and processed.")
    print(f"Training data shape: {X_train.shape}")
    print(f"Test data shape: {X_test.shape}")

    log_dir = os.path.join('Logs')
    tb_callback = TensorBoard(log_dir=log_dir)
    num_features = 258

    model = Sequential([
        GRU(64, return_sequences=True, input_shape=(sequence_length, num_features)),
        GRU(128, return_sequences=True),
        GRU(64, return_sequences=False),
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(actions.shape[0], activation='softmax')
    ])

    model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    model.summary()

    print("\nStarting model training...")
    model.fit(X_train, y_train, epochs=150, callbacks=[tb_callback], validation_data=(X_test, y_test))
    print("Model training complete.")

    model.save('asl_action_recognizer.h5')
    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    converter.optimizations = [tf.lite.Optimize.DEFAULT]
    tflite_model = converter.convert()
    with open('asl_model.tflite', 'wb') as f:
        f.write(tflite_model)
    print("Models saved successfully.")

# --- Main Execution ---
if __name__ == "__main__":
    train_model()
    print("\n✅ --- PROCESS COMPLETE --- ✅")
# Out:
# Starting video processing and data loading...
# Processing videos for action: 'obrigado'
# Processing videos for action: 'null'
#
# Data successfully loaded and processed.
# Training data shape: (334, 100, 258)
# Test data shape: (60, 100, 258)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 100, 64)        │        62,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 100, 128)       │        74,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 64)             │        37,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 180,258 (704.13 KB)
#  Trainable params: 180,258 (704.13 KB)
#  Non-trainable params: 0 (0.00 B)
# Starting model training...
# Epoch 1/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 360ms/step - categorical_accuracy: 0.5662 - loss: 0.6977 - val_categorical_accuracy: 0.6000 - val_loss: 0.6628
# Epoch 2/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 410ms/step - categorical_accuracy: 0.5752 - loss: 0.6725 - val_categorical_accuracy: 0.5667 - val_loss: 0.7106
# Epoch 3/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 289ms/step - categorical_accuracy: 0.6538 - loss: 0.6227 - val_categorical_accuracy: 0.6833 - val_loss: 0.5753
# Epoch 4/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 436ms/step - categorical_accuracy: 0.7019 - loss: 0.5734 - val_categorical_accuracy: 0.8000 - val_loss: 0.4861
# Epoch 5/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 350ms/step - categorical_accuracy: 0.7959 - loss: 0.4473 - val_categorical_accuracy: 0.8667 - val_loss: 0.3405
# Epoch 6/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - categorical_accuracy: 0.9014 - loss: 0.2922 - val_categorical_accuracy: 0.9667 - val_loss: 0.1825
# Epoch 7/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 246ms/step - categorical_accuracy: 0.8804 - loss: 0.2853 - val_categorical_accuracy: 0.8333 - val_loss: 0.3780
# Epoch 8/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 240ms/step - categorical_accuracy: 0.8957 - loss: 0.2568 - val_categorical_accuracy: 0.9167 - val_loss: 0.2215
# Epoch 9/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 369ms/step - categorical_accuracy: 0.9356 - loss: 0.1889 - val_categorical_accuracy: 0.8833 - val_loss: 0.2808
# Epoch 10/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 280ms/step - categorical_accuracy: 0.9323 - loss: 0.1979 - val_categorical_accuracy: 0.8833 - val_loss: 0.2750
# Epoch 11/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step - categorical_accuracy: 0.9115 - loss: 0.2142 - val_categorical_accuracy: 0.9167 - val_loss: 0.2144
# Epoch 12/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 246ms/step - categorical_accuracy: 0.9243 - loss: 0.1895 - val_categorical_accuracy: 0.9333 - val_loss: 0.1730
# Epoch 13/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 269ms/step - categorical_accuracy: 0.9424 - loss: 0.1437 - val_categorical_accuracy: 0.9500 - val_loss: 0.1720
# Epoch 14/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 448ms/step - categorical_accuracy: 0.9592 - loss: 0.1047 - val_categorical_accuracy: 0.9500 - val_loss: 0.1993
# Epoch 15/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 326ms/step - categorical_accuracy: 0.9405 - loss: 0.1202 - val_categorical_accuracy: 0.9500 - val_loss: 0.1664
# Epoch 16/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - categorical_accuracy: 0.9709 - loss: 0.0595 - val_categorical_accuracy: 0.9333 - val_loss: 0.1650
# Epoch 17/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 254ms/step - categorical_accuracy: 0.9897 - loss: 0.0523 - val_categorical_accuracy: 0.9167 - val_loss: 0.2899
# Epoch 18/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 424ms/step - categorical_accuracy: 0.9556 - loss: 0.0935 - val_categorical_accuracy: 0.9167 - val_loss: 0.3229
# Epoch 19/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 245ms/step - categorical_accuracy: 0.9395 - loss: 0.1379 - val_categorical_accuracy: 0.9333 - val_loss: 0.1902
# Epoch 20/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 268ms/step - categorical_accuracy: 0.9859 - loss: 0.0350 - val_categorical_accuracy: 0.9667 - val_loss: 0.1888
# Epoch 21/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 265ms/step - categorical_accuracy: 0.9777 - loss: 0.0689 - val_categorical_accuracy: 0.9333 - val_loss: 0.1585
# Epoch 22/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 386ms/step - categorical_accuracy: 0.9807 - loss: 0.0429 - val_categorical_accuracy: 0.9333 - val_loss: 0.2393
# Epoch 23/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 243ms/step - categorical_accuracy: 0.9887 - loss: 0.0370 - val_categorical_accuracy: 0.9500 - val_loss: 0.1526
# Epoch 24/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - categorical_accuracy: 0.9798 - loss: 0.0341 - val_categorical_accuracy: 0.9333 - val_loss: 0.2037
# Epoch 25/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 245ms/step - categorical_accuracy: 1.0000 - loss: 0.0176 - val_categorical_accuracy: 0.9667 - val_loss: 0.1835
# Epoch 26/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 418ms/step - categorical_accuracy: 0.9945 - loss: 0.0154 - val_categorical_accuracy: 0.9500 - val_loss: 0.2212
# Epoch 27/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 238ms/step - categorical_accuracy: 0.9947 - loss: 0.0128 - val_categorical_accuracy: 0.9500 - val_loss: 0.1717
# Epoch 28/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - categorical_accuracy: 0.9983 - loss: 0.0040 - val_categorical_accuracy: 0.9667 - val_loss: 0.1708
# Epoch 29/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 268ms/step - categorical_accuracy: 1.0000 - loss: 0.0049 - val_categorical_accuracy: 0.9333 - val_loss: 0.2652
# Epoch 30/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 383ms/step - categorical_accuracy: 1.0000 - loss: 0.0021 - val_categorical_accuracy: 0.9500 - val_loss: 0.1803
# Epoch 31/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - categorical_accuracy: 1.0000 - loss: 0.0015 - val_categorical_accuracy: 0.9500 - val_loss: 0.1654
# Epoch 32/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 241ms/step - categorical_accuracy: 1.0000 - loss: 6.0254e-04 - val_categorical_accuracy: 0.9500 - val_loss: 0.1862
# Epoch 33/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step - categorical_accuracy: 1.0000 - loss: 5.0332e-04 - val_categorical_accuracy: 0.9500 - val_loss: 0.1986
# Epoch 34/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 335ms/step - categorical_accuracy: 1.0000 - loss: 3.3583e-04 - val_categorical_accuracy: 0.9500 - val_loss: 0.2086
# Epoch 35/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 310ms/step - categorical_accuracy: 1.0000 - loss: 4.9249e-04 - val_categorical_accuracy: 0.9500 - val_loss: 0.2090
# Epoch 36/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 243ms/step - categorical_accuracy: 1.0000 - loss: 3.1659e-04 - val_categorical_accuracy: 0.9500 - val_loss: 0.2078
# Epoch 37/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - categorical_accuracy: 1.0000 - loss: 2.9789e-04 - val_categorical_accuracy: 0.9500 - val_loss: 0.2101
# Epoch 38/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 316ms/step - categorical_accuracy: 1.0000 - loss: 3.3216e-04 - val_categorical_accuracy: 0.9500 - val_loss: 0.2121
# Epoch 39/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 239ms/step - categorical_accuracy: 1.0000 - loss: 2.4420e-04 - val_categorical_accuracy: 0.9500 - val_loss: 0.2137
# Epoch 40/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 259ms/step - categorical_accuracy: 1.0000 - loss: 2.4146e-04 - val_categorical_accuracy: 0.9500 - val_loss: 0.2156
# Epoch 41/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 238ms/step - categorical_accuracy: 1.0000 - loss: 1.6768e-04 - val_categorical_accuracy: 0.9500 - val_loss: 0.2168
# Epoch 42/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 313ms/step - categorical_accuracy: 1.0000 - loss: 1.6936e-04 - val_categorical_accuracy: 0.9500 - val_loss: 0.2180
# Epoch 43/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 336ms/step - categorical_accuracy: 1.0000 - loss: 1.3893e-04 - val_categorical_accuracy: 0.9500 - val_loss: 0.2215
# Epoch 44/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 241ms/step - categorical_accuracy: 1.0000 - loss: 1.7543e-04 - val_categorical_accuracy: 0.9500 - val_loss: 0.2225
# Epoch 45/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 236ms/step - categorical_accuracy: 1.0000 - loss: 1.6192e-04 - val_categorical_accuracy: 0.9500 - val_loss: 0.2233
# Epoch 46/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 240ms/step - categorical_accuracy: 1.0000 - loss: 1.7893e-04 - val_categorical_accuracy: 0.9500 - val_loss: 0.2241
# Epoch 47/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 374ms/step - categorical_accuracy: 1.0000 - loss: 1.0926e-04 - val_categorical_accuracy: 0.9500 - val_loss: 0.2257
# Epoch 48/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 236ms/step - categorical_accuracy: 1.0000 - loss: 1.2166e-04 - val_categorical_accuracy: 0.9500 - val_loss: 0.2270
# Epoch 49/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 243ms/step - categorical_accuracy: 1.0000 - loss: 1.0167e-04 - val_categorical_accuracy: 0.9500 - val_loss: 0.2284
# Epoch 50/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 304ms/step - categorical_accuracy: 1.0000 - loss: 9.7931e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2301
# Epoch 51/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 340ms/step - categorical_accuracy: 1.0000 - loss: 9.3592e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2314
# Epoch 52/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 241ms/step - categorical_accuracy: 1.0000 - loss: 1.1228e-04 - val_categorical_accuracy: 0.9500 - val_loss: 0.2341
# Epoch 53/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 242ms/step - categorical_accuracy: 1.0000 - loss: 1.1475e-04 - val_categorical_accuracy: 0.9500 - val_loss: 0.2366
# Epoch 54/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 311ms/step - categorical_accuracy: 1.0000 - loss: 9.3495e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2377
# Epoch 55/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 240ms/step - categorical_accuracy: 1.0000 - loss: 7.0978e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2376
# Epoch 56/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step - categorical_accuracy: 1.0000 - loss: 7.6174e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2394
# Epoch 57/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - categorical_accuracy: 1.0000 - loss: 8.4230e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2411
# Epoch 58/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 425ms/step - categorical_accuracy: 1.0000 - loss: 9.8820e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2426
# Epoch 59/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - categorical_accuracy: 1.0000 - loss: 6.9978e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2425
# Epoch 60/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 246ms/step - categorical_accuracy: 1.0000 - loss: 8.9676e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2432
# Epoch 61/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 266ms/step - categorical_accuracy: 1.0000 - loss: 6.1968e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2445
# Epoch 62/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 388ms/step - categorical_accuracy: 1.0000 - loss: 9.2797e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2451
# Epoch 63/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 244ms/step - categorical_accuracy: 1.0000 - loss: 5.7898e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2465
# Epoch 64/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 239ms/step - categorical_accuracy: 1.0000 - loss: 6.0749e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2484
# Epoch 65/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 241ms/step - categorical_accuracy: 1.0000 - loss: 5.4958e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2488
# Epoch 66/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 406ms/step - categorical_accuracy: 1.0000 - loss: 4.9292e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2494
# Epoch 67/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 246ms/step - categorical_accuracy: 1.0000 - loss: 4.7745e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2505
# Epoch 68/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 239ms/step - categorical_accuracy: 1.0000 - loss: 5.2322e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2507
# Epoch 69/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 252ms/step - categorical_accuracy: 1.0000 - loss: 4.6409e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2514
# Epoch 70/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 238ms/step - categorical_accuracy: 1.0000 - loss: 4.7808e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2533
# Epoch 71/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 247ms/step - categorical_accuracy: 1.0000 - loss: 4.7585e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2545
# Epoch 72/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - categorical_accuracy: 1.0000 - loss: 4.5302e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2550
# Epoch 73/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 397ms/step - categorical_accuracy: 1.0000 - loss: 4.1622e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2557
# Epoch 74/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 243ms/step - categorical_accuracy: 1.0000 - loss: 4.1393e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2557
# Epoch 75/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 269ms/step - categorical_accuracy: 1.0000 - loss: 3.9767e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2566
# Epoch 76/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 299ms/step - categorical_accuracy: 1.0000 - loss: 5.1407e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2571
# Epoch 77/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 352ms/step - categorical_accuracy: 1.0000 - loss: 3.6069e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2569
# Epoch 78/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 245ms/step - categorical_accuracy: 1.0000 - loss: 4.5530e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2579
# Epoch 79/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 241ms/step - categorical_accuracy: 1.0000 - loss: 3.3723e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2588
# Epoch 80/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 266ms/step - categorical_accuracy: 1.0000 - loss: 3.6096e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2593
# Epoch 81/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 382ms/step - categorical_accuracy: 1.0000 - loss: 3.1325e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2604
# Epoch 82/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 250ms/step - categorical_accuracy: 1.0000 - loss: 3.4139e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2600
# Epoch 83/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 252ms/step - categorical_accuracy: 1.0000 - loss: 3.0523e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2599
# Epoch 84/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - categorical_accuracy: 1.0000 - loss: 2.9240e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2614
# Epoch 85/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 362ms/step - categorical_accuracy: 1.0000 - loss: 3.4495e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2619
# Epoch 86/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 307ms/step - categorical_accuracy: 1.0000 - loss: 2.5690e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2626
# Epoch 87/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 242ms/step - categorical_accuracy: 1.0000 - loss: 3.5080e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2625
# Epoch 88/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step - categorical_accuracy: 1.0000 - loss: 2.3112e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2623
# Epoch 89/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 362ms/step - categorical_accuracy: 1.0000 - loss: 2.9084e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2624
# Epoch 90/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 291ms/step - categorical_accuracy: 1.0000 - loss: 3.0312e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2627
# Epoch 91/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - categorical_accuracy: 1.0000 - loss: 3.0270e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2635
# Epoch 92/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 249ms/step - categorical_accuracy: 1.0000 - loss: 3.0871e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2646
# Epoch 93/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 421ms/step - categorical_accuracy: 1.0000 - loss: 2.0185e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2659
# Epoch 94/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - categorical_accuracy: 1.0000 - loss: 2.1627e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2661
# Epoch 95/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - categorical_accuracy: 1.0000 - loss: 2.6146e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2657
# Epoch 96/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 269ms/step - categorical_accuracy: 1.0000 - loss: 2.3771e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2667
# Epoch 97/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 247ms/step - categorical_accuracy: 1.0000 - loss: 2.8642e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2674
# Epoch 98/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 241ms/step - categorical_accuracy: 1.0000 - loss: 2.1154e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2673
# Epoch 99/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 246ms/step - categorical_accuracy: 1.0000 - loss: 2.0130e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2683
# Epoch 100/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 312ms/step - categorical_accuracy: 1.0000 - loss: 2.2914e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2691
# Epoch 101/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 351ms/step - categorical_accuracy: 1.0000 - loss: 2.0937e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2698
# Epoch 102/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 243ms/step - categorical_accuracy: 1.0000 - loss: 1.8121e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2689
# Epoch 103/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 251ms/step - categorical_accuracy: 1.0000 - loss: 1.9436e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2708
# Epoch 104/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 371ms/step - categorical_accuracy: 1.0000 - loss: 1.4584e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2711
# Epoch 105/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 277ms/step - categorical_accuracy: 1.0000 - loss: 2.0030e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2712
# Epoch 106/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 246ms/step - categorical_accuracy: 1.0000 - loss: 1.7864e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2720
# Epoch 107/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 366ms/step - categorical_accuracy: 1.0000 - loss: 1.8843e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2720
# Epoch 108/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 244ms/step - categorical_accuracy: 1.0000 - loss: 1.8952e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2719
# Epoch 109/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 248ms/step - categorical_accuracy: 1.0000 - loss: 1.4503e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2726
# Epoch 110/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 311ms/step - categorical_accuracy: 1.0000 - loss: 1.5963e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2724
# Epoch 111/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 342ms/step - categorical_accuracy: 1.0000 - loss: 1.4470e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2731
# Epoch 112/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 245ms/step - categorical_accuracy: 1.0000 - loss: 1.5881e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2735
# Epoch 113/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - categorical_accuracy: 1.0000 - loss: 1.6028e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2733
# Epoch 114/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 272ms/step - categorical_accuracy: 1.0000 - loss: 1.2176e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2738
# Epoch 115/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 265ms/step - categorical_accuracy: 1.0000 - loss: 1.8436e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2741
# Epoch 116/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - categorical_accuracy: 1.0000 - loss: 1.5916e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2745
# Epoch 117/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 243ms/step - categorical_accuracy: 1.0000 - loss: 1.2981e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2744
# Epoch 118/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 315ms/step - categorical_accuracy: 1.0000 - loss: 1.7618e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2745
# Epoch 119/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 344ms/step - categorical_accuracy: 1.0000 - loss: 1.2126e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2750
# Epoch 120/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 243ms/step - categorical_accuracy: 1.0000 - loss: 1.2956e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2756
# Epoch 121/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step - categorical_accuracy: 1.0000 - loss: 1.4201e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2755
# Epoch 122/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 386ms/step - categorical_accuracy: 1.0000 - loss: 1.5909e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2760
# Epoch 123/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 277ms/step - categorical_accuracy: 1.0000 - loss: 1.4462e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2758
# Epoch 124/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 248ms/step - categorical_accuracy: 1.0000 - loss: 1.1341e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2760
# Epoch 125/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 245ms/step - categorical_accuracy: 1.0000 - loss: 1.4280e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2767
# Epoch 126/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 397ms/step - categorical_accuracy: 1.0000 - loss: 1.5323e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2770
# Epoch 127/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 253ms/step - categorical_accuracy: 1.0000 - loss: 1.0884e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2779
# Epoch 128/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 244ms/step - categorical_accuracy: 1.0000 - loss: 1.4539e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2777
# Epoch 129/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 414ms/step - categorical_accuracy: 1.0000 - loss: 1.3968e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2778
# Epoch 130/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 239ms/step - categorical_accuracy: 1.0000 - loss: 1.2488e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2781
# Epoch 131/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - categorical_accuracy: 1.0000 - loss: 9.7795e-06 - val_categorical_accuracy: 0.9500 - val_loss: 0.2789
# Epoch 132/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 250ms/step - categorical_accuracy: 1.0000 - loss: 1.0565e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2791
# Epoch 133/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 291ms/step - categorical_accuracy: 1.0000 - loss: 1.0698e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2795
# Epoch 134/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 243ms/step - categorical_accuracy: 1.0000 - loss: 1.2071e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2792
# Epoch 135/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 241ms/step - categorical_accuracy: 1.0000 - loss: 1.0926e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2792
# Epoch 136/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 290ms/step - categorical_accuracy: 1.0000 - loss: 9.9617e-06 - val_categorical_accuracy: 0.9500 - val_loss: 0.2791
# Epoch 137/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 369ms/step - categorical_accuracy: 1.0000 - loss: 1.0692e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2794
# Epoch 138/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 243ms/step - categorical_accuracy: 1.0000 - loss: 1.3820e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2797
# Epoch 139/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 241ms/step - categorical_accuracy: 1.0000 - loss: 1.0513e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2796
# Epoch 140/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 332ms/step - categorical_accuracy: 1.0000 - loss: 1.1303e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2806
# Epoch 141/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 239ms/step - categorical_accuracy: 1.0000 - loss: 9.8903e-06 - val_categorical_accuracy: 0.9500 - val_loss: 0.2806
# Epoch 142/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - categorical_accuracy: 1.0000 - loss: 1.0172e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2809
# Epoch 143/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 299ms/step - categorical_accuracy: 1.0000 - loss: 9.7440e-06 - val_categorical_accuracy: 0.9500 - val_loss: 0.2807
# Epoch 144/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 350ms/step - categorical_accuracy: 1.0000 - loss: 1.1649e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2809
# Epoch 145/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 250ms/step - categorical_accuracy: 1.0000 - loss: 8.1163e-06 - val_categorical_accuracy: 0.9500 - val_loss: 0.2818
# Epoch 146/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - categorical_accuracy: 1.0000 - loss: 1.0081e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2821
# Epoch 147/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 365ms/step - categorical_accuracy: 1.0000 - loss: 9.6106e-06 - val_categorical_accuracy: 0.9500 - val_loss: 0.2822
# Epoch 148/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 308ms/step - categorical_accuracy: 1.0000 - loss: 9.4269e-06 - val_categorical_accuracy: 0.9500 - val_loss: 0.2829
# Epoch 149/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step - categorical_accuracy: 1.0000 - loss: 1.0378e-05 - val_categorical_accuracy: 0.9500 - val_loss: 0.2823
# Epoch 150/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 245ms/step - categorical_accuracy: 1.0000 - loss: 8.6885e-06 - val_categorical_accuracy: 0.9500 - val_loss: 0.2828
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model training complete.
# Saved artifact at '/tmp/tmp99sa3o1f'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 100, 258), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   137839947021008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839947019088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839947020240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839947021392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839947018896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839947020048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839947021200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839947018128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839947019664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839947021776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839947019856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839947021968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839728640464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839947018512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839728640272: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ---------------------------------------------------------------------------
# ConverterError                            Traceback (most recent call last)
# /tmp/ipython-input-3998459622.py in <cell line: 0>()
#     154 # --- Main Execution ---
#     155 if __name__ == "__main__":
# --> 156     train_model()
#     157     print("\n✅ --- PROCESS COMPLETE --- ✅")
#
# /tmp/ipython-input-3998459622.py in train_model()
#     147     converter = tf.lite.TFLiteConverter.from_keras_model(model)
#     148     converter.optimizations = [tf.lite.Optimize.DEFAULT]
# --> 149     tflite_model = converter.convert()
#     150     with open('asl_model.tflite', 'wb') as f:
#     151         f.write(tflite_model)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/lite.py in wrapper(self, *args, **kwargs)
#    1248   def wrapper(self, *args, **kwargs):
#    1249     # pylint: disable=protected-access
# -> 1250     return self._convert_and_export_metrics(convert_func, *args, **kwargs)
#    1251     # pylint: enable=protected-access
#    1252
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/lite.py in _convert_and_export_metrics(self, convert_func, *args, **kwargs)
#    1200     self._save_conversion_params_metric()
#    1201     start_time = time.process_time()
# -> 1202     result = convert_func(self, *args, **kwargs)
#    1203     elapsed_time_ms = (time.process_time() - start_time) * 1000
#    1204     if result:
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/lite.py in convert(self)
#    1766         Invalid quantization parameters.
#    1767     """
# -> 1768     saved_model_convert_result = self._convert_as_saved_model()
#    1769     if saved_model_convert_result:
#    1770       return saved_model_convert_result
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/lite.py in _convert_as_saved_model(self)
#    1747       )
#    1748       if self.saved_model_dir:
# -> 1749         return super(TFLiteKerasModelConverterV2, self).convert(
#    1750             graph_def, input_tensors, output_tensors
#    1751         )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/lite.py in convert(self, graph_def, input_tensors, output_tensors)
#    1485
#    1486     # Converts model.
# -> 1487     result = _convert_graphdef(
#    1488         input_data=graph_def,
#    1489         input_tensors=input_tensors,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert_phase.py in wrapper(*args, **kwargs)
#     210         else:
#     211           report_error_message(str(converter_error))
# --> 212         raise converter_error from None  # Re-throws the exception.
#     213       except Exception as error:
#     214         report_error_message(str(error))
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert_phase.py in wrapper(*args, **kwargs)
#     203     def wrapper(*args, **kwargs):
#     204       try:
# --> 205         return func(*args, **kwargs)
#     206       except ConverterError as converter_error:
#     207         if converter_error.errors:
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py in convert_graphdef(input_data, input_tensors, output_tensors, **kwargs)
#     883       model_flags.output_arrays.append(util.get_tensor_name(output_tensor))
#     884
# --> 885   data = convert(
#     886       model_flags,
#     887       conversion_flags,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py in convert(model_flags, conversion_flags, input_data_str, debug_info_str)
#     348             debug_info_str,
#     349         )
# --> 350     raise converter_error
#     351
#     352
#
# ConverterError: <unknown>:0: error: loc(callsite(callsite(fused["TensorListReserve:", "sequential_1/gru_1/TensorArrayV2_1@__inference_function_64307"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_64378"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): 'tf.TensorListReserve' op requires element_shape to be static during TF Lite transformation pass
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"]): called from
# <unknown>:0: error: loc(callsite(callsite(fused["TensorListReserve:", "sequential_1/gru_1/TensorArrayV2_1@__inference_function_64307"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_64378"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): failed to legalize operation 'tf.TensorListReserve' that was explicitly marked illegal
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"]): called from
# <unknown>:0: error: Lowering tensor list ops is failed. Please consider using Select TF ops and disabling `_experimental_lower_tensor_list_ops` flag in the TFLite converter object. For example, converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS, tf.lite.OpsSet.SELECT_TF_OPS]\n converter._experimental_lower_tensor_list_ops = False

# %%
import tensorflow as tf

# --- Configuration ---
# The path to your saved Keras .h5 model file
H5_MODEL_PATH = '/content/asl_action_recognizer.h5'

# The desired path for the output .tflite model file
TFLITE_MODEL_PATH = '/content/asl_model.tflite'

print(f"Loading Keras model from: {H5_MODEL_PATH}")

# 1. Load the Keras model
try:
    model = tf.keras.models.load_model(H5_MODEL_PATH)
    print("Model loaded successfully.")
except Exception as e:
    print(f"Error loading model: {e}")
    exit()

# 2. Create a TFLite converter from the Keras model
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# 3. **Apply the fix for the GRU/LSTM conversion error**
# This tells the converter to use a broader set of operations
converter.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS,  # Enable TFLite builtin ops
    tf.lite.OpsSet.SELECT_TF_OPS    # Enable TensorFlow ops
]
converter._experimental_lower_tensor_list_ops = False

# 4. (Optional) Apply optimizations for mobile deployment
converter.optimizations = [tf.lite.Optimize.DEFAULT]

print("\nStarting TFLite conversion...")

# 5. Perform the conversion
try:
    tflite_model = converter.convert()
    print("Conversion successful.")
except Exception as e:
    print(f"Error during conversion: {e}")
    exit()

# 6. Save the converted model to a file
with open(TFLITE_MODEL_PATH, 'wb') as f:
    f.write(tflite_model)

print(f"\nTFLite model saved successfully to: {TFLITE_MODEL_PATH}")
print("You can now use this '.tflite' file in your Android Studio project.")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Loading Keras model from: /content/asl_action_recognizer.h5
# Model loaded successfully.
#
# Starting TFLite conversion...
# Saved artifact at '/tmp/tmpl0rfn94b'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 100, 258), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   137839049594000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839049595728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839049595536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839049591888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839049594576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839049594192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839049591120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839049594768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839049593040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839049592080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839049592464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839049591504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839049590736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839049591312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137839049589584: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Conversion successful.
#
# TFLite model saved successfully to: /content/asl_model.tflite
# You can now use this '.tflite' file in your Android Studio project.

# %%
import cv2
import numpy as np
import os
import tensorflow as tf
import mediapipe as mp
import warnings

# Suppress Protobuf deprecation warning from MediaPipe
warnings.filterwarnings("ignore", category=UserWarning, module='google.protobuf.symbol_database')

# --- Part 1: Configuration & Setup ---

# *** IMPORTANT: SET THIS TO THE FOLDER WITH YOUR TEST VIDEOS ***
VIDEO_TEST_FOLDER = '/content/testes' # <-- CHANGE THIS

# --- Paths to your models ---
H5_MODEL_PATH = 'asl_action_recognizer.h5'
POSE_MODEL_PATH = 'pose_landmarker_lite.task'
HAND_MODEL_PATH = 'hand_landmarker.task'

# --- Model & Detection Parameters ---
actions = np.array(['obrigado', 'null']) # Must be the same as in training
sequence_length = 100 # Must be the same as in training
CONFIDENCE_THRESHOLD = 0.7 # Only show predictions with >= 70% confidence

# Check for model files
if not all(os.path.exists(p) for p in [H5_MODEL_PATH, POSE_MODEL_PATH, HAND_MODEL_PATH]):
    print("Error: Make sure your .h5 model and the MediaPipe .task files are in the correct directory.")
    exit()

# --- Part 2: MediaPipe Setup and Helper Functions ---

from mediapipe.tasks import python
from mediapipe.tasks.python import vision

# Use the stable IMAGE mode for processing video frames
base_options = python.BaseOptions
PoseLandmarker = vision.PoseLandmarker
PoseLandmarkerOptions = vision.PoseLandmarkerOptions
HandLandmarker = vision.HandLandmarker
HandLandmarkerOptions = vision.HandLandmarkerOptions
VisionRunningMode = vision.RunningMode

pose_options = PoseLandmarkerOptions(
    base_options=base_options(model_asset_path=POSE_MODEL_PATH), running_mode=VisionRunningMode.IMAGE)
hand_options = HandLandmarkerOptions(
    base_options=base_options(model_asset_path=HAND_MODEL_PATH), running_mode=VisionRunningMode.IMAGE, num_hands=2)

def extract_keypoints(pose_result, hand_result):
    """Extracts landmark data into a numpy array from Pose and Hand landmark results."""
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in pose_result.pose_landmarks[0]]).flatten() if pose_result.pose_landmarks else np.zeros(33 * 4)
    lh, rh = np.zeros(21 * 3), np.zeros(21 * 3)
    if hand_result.hand_landmarks:
        for i, hand_landmarks in enumerate(hand_result.hand_landmarks):
            handedness = hand_result.handedness[i][0].category_name
            if handedness == "Left": lh = np.array([[res.x, res.y, res.z] for res in hand_landmarks]).flatten()
            elif handedness == "Right": rh = np.array([[res.x, res.y, res.z] for res in hand_landmarks]).flatten()
    return np.concatenate([pose, lh, rh])

# --- Part 3: Main Inference Logic ---

def analyze_videos():
    # Load the trained Keras model
    model = tf.keras.models.load_model(H5_MODEL_PATH)
    print("Model loaded successfully.")

    # Create the MediaPipe landmarker objects
    with PoseLandmarker.create_from_options(pose_options) as pose_landmarker, \
         HandLandmarker.create_from_options(hand_options) as hand_landmarker:

        # Iterate through all video files in the specified folder
        for video_file in sorted(os.listdir(VIDEO_TEST_FOLDER)):
            if not video_file.lower().endswith('.mp4'):
                continue

            video_path = os.path.join(VIDEO_TEST_FOLDER, video_file)
            cap = cv2.VideoCapture(video_path)

            frame_landmarks = []
            while True:
                ret, frame = cap.read()
                if not ret:
                    break

                # Convert frame and run detection
                mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
                pose_result = pose_landmarker.detect(mp_image)
                hand_result = hand_landmarker.detect(mp_image)

                keypoints = extract_keypoints(pose_result, hand_result)
                frame_landmarks.append(keypoints)

            cap.release()

            # --- Prepare sequence for the model ---
            if not frame_landmarks:
                print(f"\nVideo: {video_file}")
                print("Result: Could not process video, no frames found.")
                continue

            # Pad or sample the sequence to match the required length
            if len(frame_landmarks) >= sequence_length:
                indices = np.linspace(0, len(frame_landmarks) - 1, sequence_length, dtype=int)
                final_sequence = [frame_landmarks[i] for i in indices]
            else:
                final_sequence = frame_landmarks
                padding = [frame_landmarks[-1]] * (sequence_length - len(frame_landmarks))
                final_sequence.extend(padding)

            # --- Make Prediction ---
            prediction = model.predict(np.expand_dims(final_sequence, axis=0))[0]
            predicted_action = actions[np.argmax(prediction)]
            confidence = prediction[np.argmax(prediction)]

            # --- Print the Result ---
            print(f"\nVideo: {video_file}")
            if confidence >= CONFIDENCE_THRESHOLD:
                print(f"Result: Found sign '{predicted_action}' with {confidence:.2%} confidence.")
            else:
                print(f"Result: No sign detected with high confidence. (Best guess: '{predicted_action}' at {confidence:.2%})")

# --- Main Execution ---
if __name__ == "__main__":
    if os.path.isdir(VIDEO_TEST_FOLDER):
        analyze_videos()
    else:
        print(f"Error: The folder '{VIDEO_TEST_FOLDER}' does not exist. Please check the path.")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded successfully.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 611ms/step
#
# Video: WhatsApp Video 2025-09-25 at 7.24.29 PM.mp4
# Result: Found sign 'obrigado' with 100.00% confidence.
